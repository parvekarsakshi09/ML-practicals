# %% [markdown]
# <a href="https://colab.research.google.com/github/parvekarsakshi09/ML-practicals/blob/main/decision_tree_for_tennis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Sakshi Parvekar")
print("2021BIT024")
# Out:
# Sakshi Parvekar
# 2021BIT024

# %% [markdown]
# ### Importing libraries and dataset

# %%
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold, cross_val_score
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree

# %%
data = pd.read_csv(r"C:\dataset\tennis - tennis.csv")

# %% [markdown]
# ### EDA

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   outlook   14 non-null     object
#  1   temp      14 non-null     object
#  2   humidity  14 non-null     object
#  3   windy     14 non-null     bool
#  4   play      14 non-null     object
# dtypes: bool(1), object(4)
# memory usage: 594.0+ bytes

# %%
data.head()
# Out:
#     outlook  temp humidity  windy play
# 0     sunny   hot     high  False   no
# 1     sunny   hot     high   True   no
# 2  overcast   hot     high  False  yes
# 3     rainy  mild     high  False  yes
# 4     rainy  cool   normal  False  yes

# %%
data.describe()
# Out:
#        outlook  temp humidity  windy play
# count       14    14       14     14   14
# unique       3     3        2      2    2
# top      sunny  mild     high  False  yes
# freq         5     6        7      8    9

# %%
data.dropna(inplace=True)

# %%
data_encoded = pd.get_dummies(data, drop_first=True)

# %%
x= data_encoded.drop('play_yes', axis=1)
y = data_encoded['play_yes']

# %% [markdown]
# ### spliting the data

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42, stratify=y)

# %% [markdown]
# ### Decision tree using entropy

# %%
dt_classifier_entropy = DecisionTreeClassifier(criterion='entropy')

# %%
dt_classifier_entropy.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred_entropy = dt_classifier_entropy.predict(x_test)

# %%
accuracy_entropy = accuracy_score(y_test, y_pred_entropy)
precision_entropy = precision_score(y_test, y_pred_entropy)
recall_entropy = recall_score(y_test, y_pred_entropy)
f1_entropy = f1_score(y_test, y_pred_entropy)
conf_matrix_entropy = confusion_matrix(y_test, y_pred_entropy)
# Out:
# C:\Users\NetComm\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("Evaluation Metrics with Criterion 'entropy':")
print("Accuracy:", accuracy_entropy)
print("Precision:", precision_entropy)
print("Recall:", recall_entropy)
print("F1-score:", f1_entropy)
print("Confusion Matrix:\n", conf_matrix_entropy)
# Out:
# Evaluation Metrics with Criterion 'entropy':
# Accuracy: 0.3333333333333333
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
# Confusion Matrix:
#  [[1 0]
#  [2 0]]

# %%
features1=x.columns
features1
# Out:
# Index(['windy', 'outlook_rainy', 'outlook_sunny', 'temp_hot', 'temp_mild',
#        'humidity_normal'],
#       dtype='object')

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20,15),dpi= 80)
class_labels = ['Negative', 'Positive']
plot_tree(dt_classifier_entropy, filled=True, feature_names=list(features1), class_names=['0', '1'])
plt.title("Decision Tree of Tennis Dataset")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
cmt=confusion_matrix(y_test,y_pred_entropy)
plt.figure(figsize=(8,6))
sns.heatmap(cmt,annot=True,cmap='Blues',fmt='g',cbar=False)
plt.xlabel('predicted lable')
plt.ylabel('True lables')
plt.title('confusion Matrix')
plt.show()

# %% [markdown]
# ### Decision tree using gii index

# %%
dt_classifier_gini = DecisionTreeClassifier(criterion='gini')

# %%
dt_classifier_gini.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_classifier_gini.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_gini = dt_classifier_gini.predict(X_test)

# %%
accuracy_gini = accuracy_score(y_test, y_pred_gini)
precision_gini = precision_score(y_test, y_pred_gini)
recall_gini = recall_score(y_test, y_pred_gini)
f1_gini = f1_score(y_test, y_pred_gini)
conf_matrix_gini = confusion_matrix(y_test, y_pred_gini)
# Out:
# C:\Users\NetComm\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
print("\nEvaluation Metrics with Criterion 'gini':")
print("Accuracy:", accuracy_gini)
print("Precision:", precision_gini)
print("Recall:", recall_gini)
print("F1-score:", f1_gini)
print("Confusion Matrix:\n", conf_matrix_gini)
# Out:
# Evaluation Metrics with Criterion 'gini':
# Accuracy: 0.3333333333333333
# Precision: 0.0
# Recall: 0.0
# F1-score: 0.0
# Confusion Matrix:
#  [[1 0]
#  [2 0]]

# %%
features=x.columns
features
# Out:
# Index(['windy', 'outlook_rainy', 'outlook_sunny', 'temp_hot', 'temp_mild',
#        'humidity_normal'],
#       dtype='object')

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(20,15),dpi= 80)
class_labels = ['Negative', 'Positive']
plot_tree(dt_classifier_gini, filled=True, feature_names=list(features), class_names=['0', '1'])
plt.title("Decision Tree of tennis Dataset")
plt.show()

# %%
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
cmt=confusion_matrix(y_test,y_pred_gini)
plt.figure(figsize=(8,6))
sns.heatmap(cmt,annot=True,cmap='Blues',fmt='g',cbar=False)
plt.xlabel('predicted lable')
plt.ylabel('True lables')
plt.title('confusion Matrix')
plt.show()
